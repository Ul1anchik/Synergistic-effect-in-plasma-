# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Чтение данных из файла
filename = 'spcpz_PAM_7x3_cut16.dat'  

data = np.loadtxt(filename)
x = data[:, 0]  # первая колонка - X
y = data[:, 1]  # вторая колонка - Y

# Построение графика
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', linewidth=2)  # синяя линия
plt.xlabel('X ось')
plt.ylabel('Y ось')
plt.title('График из файла .dat')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# MA= 0.8798879456334701

# %%
def extract_data_slice(filename, x_min, x_max):
    """
    Вырезает данные в указанном диапазоне по оси X
    """
    # Чтение всех данных
    data = np.loadtxt(filename)
    x_all = data[:, 0]
    y_all = data[:, 1]
    
    # Поиск индексов в заданном диапазоне
    mask = (x_all >= x_min) & (x_all <= x_max)
    x_slice = x_all[mask]
    y_slice = y_all[mask]
    
    return x_slice, y_slice, x_all, y_all

# Параметры вырезки
filename = 'spcpz_PAM_7x3_cut16.dat'
x_min = 11.0  # начальное значение X
x_max = 15.65  # конечное значение X

# Вырезка данных
x_slice, y_slice, x_all, y_all = extract_data_slice(filename, x_min, x_max)

# Построение графиков
plt.figure(figsize=(12, 6))

# Полный график
plt.subplot(1, 2, 1)
plt.plot(x_all, y_all, 'gray', alpha=0.5, label='Все данные')
plt.axvspan(x_min, x_max, color='red', alpha=0.2, label='Вырезаемая область')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Все данные с выделением области')
plt.legend()
plt.grid(True, alpha=0.3)

# Вырезанный кусок
plt.subplot(1, 2, 2)
plt.plot(x_slice, y_slice, 'b-', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Вырезанный кусок: X от {x_min} до {x_max}')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Вырезано {len(x_slice)} точек из {len(x_all)}")


# После вырезки данных


# Сохранение в файл .dat
np.savetxt('piece_1.dat', 
           np.column_stack((x_slice, y_slice)),  # объединяем X и Y в один массив
           fmt='%.6f',                          # формат чисел (6 знаков после запятой)
           delimiter='\t',                      # разделитель - табуляция
                                 
           comments='')                         # убираем символ комментария перед header

print(f"Данные сохранены в 'piece_1.dat'")
# Out:
# Вырезано 391 точек из 2689
# Данные сохранены в 'piece_1.dat'

# %%
filename = 'spcpz_PAM_7x3_cut16.dat'
x_min = 5.60  # начальное значение X
x_max = 11.0  # конечное значение X

# Вырезка данных
x_slice, y_slice, x_all, y_all = extract_data_slice(filename, x_min, x_max)

# Построение графиков
plt.figure(figsize=(12, 6))

# Полный график
plt.subplot(1, 2, 1)
plt.plot(x_all, y_all, 'gray', alpha=0.5, label='Все данные')
plt.axvspan(x_min, x_max, color='red', alpha=0.2, label='Вырезаемая область')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Все данные с выделением области')
plt.legend()
plt.grid(True, alpha=0.3)

# Вырезанный кусок
plt.subplot(1, 2, 2)
plt.plot(x_slice, y_slice, 'b-', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Вырезанный кусок: X от {x_min} до {x_max}')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Вырезано {len(x_slice)} точек из {len(x_all)}")


# После вырезки данных


# Сохранение в файл .dat
np.savetxt('piece_2.dat', 
           np.column_stack((x_slice, y_slice)),  # объединяем X и Y в один массив
           fmt='%.6f',                          # формат чисел (6 знаков после запятой)
           delimiter='\t',                      # разделитель - табуляция
                                 
           comments='')                         # убираем символ комментария перед header

print(f"Данные сохранены в 'piece_2.dat'")
# Out:
# Вырезано 453 точек из 2689
# Данные сохранены в 'piece_2.dat'

# %%
filename = 'spcpz_PAM_7x3_cut16.dat'
x_min = 2.50  # начальное значение X
x_max = 5.60  # конечное значение X

# Вырезка данных
x_slice, y_slice, x_all, y_all = extract_data_slice(filename, x_min, x_max)

# Построение графиков
plt.figure(figsize=(12, 6))

# Полный график
plt.subplot(1, 2, 1)
plt.plot(x_all, y_all, 'gray', alpha=0.5, label='Все данные')
plt.axvspan(x_min, x_max, color='red', alpha=0.2, label='Вырезаемая область')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Все данные с выделением области')
plt.legend()
plt.grid(True, alpha=0.3)

# Вырезанный кусок
plt.subplot(1, 2, 2)
plt.plot(x_slice, y_slice, 'b-', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Вырезанный кусок: X от {x_min} до {x_max}')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Вырезано {len(x_slice)} точек из {len(x_all)}")


# После вырезки данных


# Сохранение в файл .dat
np.savetxt('piece_3.dat', 
           np.column_stack((x_slice, y_slice)),  # объединяем X и Y в один массив
           fmt='%.6f',                          # формат чисел (6 знаков после запятой)
           delimiter='\t',                      # разделитель - табуляция
                                 
           comments='')                         # убираем символ комментария перед header

print(f"Данные сохранены в 'piece_3.dat'")
# Out:
# Вырезано 261 точек из 2689
# Данные сохранены в 'piece_3.dat'

# %%
filename = 'spcpz_PAM_7x3_cut16.dat'
x_min = 0  # начальное значение X
x_max = 2.50  # конечное значение X

# Вырезка данных
x_slice, y_slice, x_all, y_all = extract_data_slice(filename, x_min, x_max)

# Построение графиков
plt.figure(figsize=(12, 6))

# Полный график
plt.subplot(1, 2, 1)
plt.plot(x_all, y_all, 'gray', alpha=0.5, label='Все данные')
plt.axvspan(x_min, x_max, color='red', alpha=0.2, label='Вырезаемая область')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Все данные с выделением области')
plt.legend()
plt.grid(True, alpha=0.3)

# Вырезанный кусок
plt.subplot(1, 2, 2)
plt.plot(x_slice, y_slice, 'b-', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Вырезанный кусок: X от {x_min} до {x_max}')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Вырезано {len(x_slice)} точек из {len(x_all)}")


# После вырезки данных


# Сохранение в файл .dat
np.savetxt('piece_4.dat', 
           np.column_stack((x_slice, y_slice)),  # объединяем X и Y в один массив
           fmt='%.6f',                          # формат чисел (6 знаков после запятой)
           delimiter='\t',                      # разделитель - табуляция
                                 
           comments='')                         # убираем символ комментария перед header

print(f"Данные сохранены в 'piece_4.dat'")
# Out:
# Вырезано 210 точек из 2689
# Данные сохранены в 'piece_4.dat'

# %%
filename = 'spcpz_PAM_7x3_cut16.dat'
x_min = -15.00  # начальное значение X
x_max = -10.70  # конечное значение X

# Вырезка данных
x_slice, y_slice, x_all, y_all = extract_data_slice(filename, x_min, x_max)

# Построение графиков
plt.figure(figsize=(12, 6))

# Полный график
plt.subplot(1, 2, 1)
plt.plot(x_all, y_all, 'gray', alpha=0.5, label='Все данные')
plt.axvspan(x_min, x_max, color='red', alpha=0.2, label='Вырезаемая область')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Все данные с выделением области')
plt.legend()
plt.grid(True, alpha=0.3)

# Вырезанный кусок
plt.subplot(1, 2, 2)
plt.plot(x_slice, y_slice, 'b-', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Вырезанный кусок: X от {x_min} до {x_max}')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Вырезано {len(x_slice)} точек из {len(x_all)}")


# После вырезки данных


# Сохранение в файл .dat
np.savetxt('piece_pos1.dat', 
           np.column_stack((x_slice, y_slice)),  # объединяем X и Y в один массив
           fmt='%.6f',                          # формат чисел (6 знаков после запятой)
           delimiter='\t',                      # разделитель - табуляция
                                 
           comments='')                         # убираем символ комментария перед header

print(f"Данные сохранены в 'piece_pos1.dat'")
# Out:
# Вырезано 361 точек из 2689
# Данные сохранены в 'piece_pos1.dat'

# %%
filename = 'spcpz_PAM_7x3_cut16.dat'
x_min = -10.70   # начальное значение X
x_max = -7.40  # конечное значение X

# Вырезка данных
x_slice, y_slice, x_all, y_all = extract_data_slice(filename, x_min, x_max)

# Построение графиков
plt.figure(figsize=(12, 6))

# Полный график
plt.subplot(1, 2, 1)
plt.plot(x_all, y_all, 'gray', alpha=0.5, label='Все данные')
plt.axvspan(x_min, x_max, color='red', alpha=0.2, label='Вырезаемая область')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Все данные с выделением области')
plt.legend()
plt.grid(True, alpha=0.3)

# Вырезанный кусок
plt.subplot(1, 2, 2)
plt.plot(x_slice, y_slice, 'b-', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Вырезанный кусок: X от {x_min} до {x_max}')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Вырезано {len(x_slice)} точек из {len(x_all)}")


# После вырезки данных


# Сохранение в файл .dat
np.savetxt('piece_pos2.dat', 
           np.column_stack((x_slice, y_slice)),  # объединяем X и Y в один массив
           fmt='%.6f',                          # формат чисел (6 знаков после запятой)
           delimiter='\t',                      # разделитель - табуляция
                                 
           comments='')                         # убираем символ комментария перед header

print(f"Данные сохранены в 'piece_pos2.dat'")
# Out:
# Вырезано 277 точек из 2689
# Данные сохранены в 'piece_pos2.dat'

# %%
filename = 'spcpz_PAM_7x3_cut16.dat'
x_min = -7.40  # начальное значение X
x_max = -4.50  # конечное значение X

# Вырезка данных
x_slice, y_slice, x_all, y_all = extract_data_slice(filename, x_min, x_max)

# Построение графиков
plt.figure(figsize=(12, 6))

# Полный график
plt.subplot(1, 2, 1)
plt.plot(x_all, y_all, 'gray', alpha=0.5, label='Все данные')
plt.axvspan(x_min, x_max, color='red', alpha=0.2, label='Вырезаемая область')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Все данные с выделением области')
plt.legend()
plt.grid(True, alpha=0.3)

# Вырезанный кусок
plt.subplot(1, 2, 2)
plt.plot(x_slice, y_slice, 'b-', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Вырезанный кусок: X от {x_min} до {x_max}')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Вырезано {len(x_slice)} точек из {len(x_all)}")


# После вырезки данных


# Сохранение в файл .dat
np.savetxt('piece_pos3.dat', 
           np.column_stack((x_slice, y_slice)),  # объединяем X и Y в один массив
           fmt='%.6f',                          # формат чисел (6 знаков после запятой)
           delimiter='\t',                      # разделитель - табуляция
                                 
           comments='')                         # убираем символ комментария перед header

print(f"Данные сохранены в 'piece_pos3.dat'")
# Out:
# Вырезано 244 точек из 2689
# Данные сохранены в 'piece_pos3.dat'

# %%
filename = 'spcpz_PAM_7x3_cut16.dat'
x_min = -4.50   # начальное значение X
x_max = 0 # конечное значение X

# Вырезка данных
x_slice, y_slice, x_all, y_all = extract_data_slice(filename, x_min, x_max)

# Построение графиков
plt.figure(figsize=(12, 6))

# Полный график
plt.subplot(1, 2, 1)
plt.plot(x_all, y_all, 'gray', alpha=0.5, label='Все данные')
plt.axvspan(x_min, x_max, color='red', alpha=0.2, label='Вырезаемая область')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Все данные с выделением области')
plt.legend()
plt.grid(True, alpha=0.3)

# Вырезанный кусок
plt.subplot(1, 2, 2)
plt.plot(x_slice, y_slice, 'b-', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Вырезанный кусок: X от {x_min} до {x_max}')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Вырезано {len(x_slice)} точек из {len(x_all)}")


# После вырезки данных


# Сохранение в файл .dat
np.savetxt('piece_pos4.dat', 
           np.column_stack((x_slice, y_slice)),  # объединяем X и Y в один массив
           fmt='%.6f',                          # формат чисел (6 знаков после запятой)
           delimiter='\t',                      # разделитель - табуляция
                                 
           comments='')                         # убираем символ комментария перед header

print(f"Данные сохранены в 'piece_pos4.dat'")
# Out:
# Вырезано 378 точек из 2689
# Данные сохранены в 'piece_pos4.dat'

# %%
filename = 'spcpz_PAM_7x3_cut16.dat'
x_min = -4.50   # начальное значение X
x_max = 5.50 # конечное значение X

# Вырезка данных
x_slice, y_slice, x_all, y_all = extract_data_slice(filename, x_min, x_max)

# Построение графиков
plt.figure(figsize=(12, 6))

# Полный график
plt.subplot(1, 2, 1)
plt.plot(x_all, y_all, 'gray', alpha=0.5, label='Все данные')
plt.axvspan(x_min, x_max, color='red', alpha=0.2, label='Вырезаемая область')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Все данные с выделением области')
plt.legend()
plt.grid(True, alpha=0.3)

# Вырезанный кусок
plt.subplot(1, 2, 2)
plt.plot(x_slice, y_slice, 'b-', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Вырезанный кусок: X от {x_min} до {x_max}')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Вырезано {len(x_slice)} точек из {len(x_all)}")


# После вырезки данных


# Сохранение в файл .dat
np.savetxt('peak1.dat', 
           np.column_stack((x_slice, y_slice)),  # объединяем X и Y в один массив
           fmt='%.6f',                          # формат чисел (6 знаков после запятой)
           delimiter='\t',                      # разделитель - табуляция
                                 
           comments='')                         # убираем символ комментария перед header

print(f"Данные сохранены в 'peak1.dat'")
# Out:
# Вырезано 839 точек из 2689
# Данные сохранены в 'peak1.dat'

# %% [markdown]
# MA= 1.64970634436641
