# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
data = np.loadtxt('spectrum_7x3_3a_filtered.dat')

# %% [markdown]
# # Вырезаем по x (Ntor)

# %% [markdown]
# # Первые пики

# %%
# 1 peak right

if data.ndim == 2 and data.shape[1] >= 3:
    x = data[:, 0]  # первая координата
    y = data[:, 1]  # вторая координата  
    z = data[:, 2]  # значение спектра

    # Вырезаем область по X 
    x_min, x_max = 0, 6.0
    mask_cut = (x >= x_min) & (x <= x_max)
    
    # Применяем маску
    data_cut = data[mask_cut]
    x_cut = data_cut[:, 0]
    y_cut = data_cut[:, 1]
    z_cut = data_cut[:, 2]

np.savetxt('spec_right_1.dat', data_cut, delimiter=' ')

# Визуализация
fig = plt.figure(figsize=(12, 5))

# Полные данные
ax1 = fig.add_subplot(131, projection='3d')
sc1 = ax1.scatter(x, y, z, c=z, cmap='viridis')
ax1.set_title('Все данные')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Spectrum')

# Вырезанная область
ax2 = fig.add_subplot(132, projection='3d')
sc2 = ax2.scatter(x_cut, y_cut, z_cut, c=z_cut, cmap='viridis')
ax2.set_title(f'Вырезанная область: X ∈ [{x_min}, {x_max}]')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Spectrum')

# 2D карта
ax3 = fig.add_subplot(133)
sc3 = ax3.scatter(x, y, c=z, cmap='viridis', s=20)
ax3.set_title('2D Map - проекция X-Y')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
plt.colorbar(sc3, ax=ax3, label='Spectrum')


import matplotlib.patches as patches
rect = patches.Rectangle((x_min, y.min()), x_max - x_min, y.max() - y.min(),
                        linewidth=2, edgecolor='red', facecolor='none', linestyle='--')
ax3.add_patch(rect)
ax3.text(x_min, y.min(), 'Вырезанная\nобласть', color='red', va='top')

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Проекция X-Z
axes[0].scatter(x[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[0].scatter(x[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[0].set_xlabel('X (Ntor)')
axes[0].set_ylabel('Spectrum (Px)')
axes[0].set_title('Проекция X-Z')
axes[0].axvline(x=x_min, color='green', linestyle='--')
axes[0].axvline(x=x_max, color='green', linestyle='--')

# Проекция Y-Z
axes[1].scatter(y[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[1].scatter(y[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[1].set_xlabel('Y (Npol)')
axes[1].set_ylabel('Spectrum (Px)')
axes[1].set_title('Проекция Y-Z')

# Проекция X-Y
sc1 = axes[2].scatter(x[~mask_cut], y[~mask_cut], c=z[~mask_cut], 
                     cmap='Blues', alpha=0.5, s=10)
sc2 = axes[2].scatter(x[mask_cut], y[mask_cut], c=z[mask_cut], 
                     cmap='Reds', alpha=0.8, s=20)
axes[2].set_xlabel('X (Ntor)')
axes[2].set_ylabel('Y (Npol)')
axes[2].set_title('Проекция X-Y')
axes[2].axvline(x=x_min, color='green', linestyle='--')
axes[2].axvline(x=x_max, color='green', linestyle='--')



plt.tight_layout()
plt.show()

# %%
# 1 peak LEFT

if data.ndim == 2 and data.shape[1] >= 3:
    x = data[:, 0]  # первая координата
    y = data[:, 1]  # вторая координата  
    z = data[:, 2]  # значение спектра

    # Вырезаем область по X 
    x_min, x_max = -4.5, 0
    mask_cut = (x >= x_min) & (x <= x_max)
    
    # Применяем маску
    data_cut = data[mask_cut]
    x_cut = data_cut[:, 0]
    y_cut = data_cut[:, 1]
    z_cut = data_cut[:, 2]

np.savetxt('spec_left_1.dat', data_cut, delimiter=' ')

# Визуализация
fig = plt.figure(figsize=(12, 5))

# Полные данные
ax1 = fig.add_subplot(131, projection='3d')
sc1 = ax1.scatter(x, y, z, c=z, cmap='viridis')
ax1.set_title('Все данные')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Spectrum')

# Вырезанная область
ax2 = fig.add_subplot(132, projection='3d')
sc2 = ax2.scatter(x_cut, y_cut, z_cut, c=z_cut, cmap='viridis')
ax2.set_title(f'Вырезанная область: X ∈ [{x_min}, {x_max}]')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Spectrum')

# 2D карта
ax3 = fig.add_subplot(133)
sc3 = ax3.scatter(x, y, c=z, cmap='viridis', s=20)
ax3.set_title('2D Map - проекция X-Y')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
plt.colorbar(sc3, ax=ax3, label='Spectrum')


import matplotlib.patches as patches
rect = patches.Rectangle((x_min, y.min()), x_max - x_min, y.max() - y.min(),
                        linewidth=2, edgecolor='red', facecolor='none', linestyle='--')
ax3.add_patch(rect)
ax3.text(x_min, y.min(), 'Вырезанная\nобласть', color='red', va='top')

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Проекция X-Z
axes[0].scatter(x[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[0].scatter(x[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[0].set_xlabel('X (Ntor)')
axes[0].set_ylabel('Spectrum (Px)')
axes[0].set_title('Проекция X-Z')
axes[0].axvline(x=x_min, color='green', linestyle='--')
axes[0].axvline(x=x_max, color='green', linestyle='--')

# Проекция Y-Z
axes[1].scatter(y[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[1].scatter(y[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[1].set_xlabel('Y (Npol)')
axes[1].set_ylabel('Spectrum (Px)')
axes[1].set_title('Проекция Y-Z')

# Проекция X-Y
sc1 = axes[2].scatter(x[~mask_cut], y[~mask_cut], c=z[~mask_cut], 
                     cmap='Blues', alpha=0.5, s=10)
sc2 = axes[2].scatter(x[mask_cut], y[mask_cut], c=z[mask_cut], 
                     cmap='Reds', alpha=0.8, s=20)
axes[2].set_xlabel('X (Ntor)')
axes[2].set_ylabel('Y (Npol)')
axes[2].set_title('Проекция X-Y')
axes[2].axvline(x=x_min, color='green', linestyle='--')
axes[2].axvline(x=x_max, color='green', linestyle='--')



plt.tight_layout()
plt.show()

# %% [markdown]
# # Вторые пики

# %%
# 2 peak LEFT

if data.ndim == 2 and data.shape[1] >= 3:
    x = data[:, 0]  # первая координата
    y = data[:, 1]  # вторая координата  
    z = data[:, 2]  # значение спектра

    # Вырезаем область по X 
    x_min, x_max = -7.5, -4.5
    mask_cut = (x >= x_min) & (x <= x_max)
    
    # Применяем маску
    data_cut = data[mask_cut]
    x_cut = data_cut[:, 0]
    y_cut = data_cut[:, 1]
    z_cut = data_cut[:, 2]

np.savetxt('spec_left_2.dat', data_cut, delimiter=' ')

# Визуализация
fig = plt.figure(figsize=(12, 5))

# Полные данные
ax1 = fig.add_subplot(131, projection='3d')
sc1 = ax1.scatter(x, y, z, c=z, cmap='viridis')
ax1.set_title('Все данные')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Spectrum')

# Вырезанная область
ax2 = fig.add_subplot(132, projection='3d')
sc2 = ax2.scatter(x_cut, y_cut, z_cut, c=z_cut, cmap='viridis')
ax2.set_title(f'Вырезанная область: X ∈ [{x_min}, {x_max}]')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Spectrum')

# 2D карта
ax3 = fig.add_subplot(133)
sc3 = ax3.scatter(x, y, c=z, cmap='viridis', s=20)
ax3.set_title('2D Map - проекция X-Y')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
plt.colorbar(sc3, ax=ax3, label='Spectrum')


import matplotlib.patches as patches
rect = patches.Rectangle((x_min, y.min()), x_max - x_min, y.max() - y.min(),
                        linewidth=2, edgecolor='red', facecolor='none', linestyle='--')
ax3.add_patch(rect)
ax3.text(x_min, y.min(), 'Вырезанная\nобласть', color='red', va='top')

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Проекция X-Z
axes[0].scatter(x[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[0].scatter(x[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[0].set_xlabel('X (Ntor)')
axes[0].set_ylabel('Spectrum (Px)')
axes[0].set_title('Проекция X-Z')
axes[0].axvline(x=x_min, color='green', linestyle='--')
axes[0].axvline(x=x_max, color='green', linestyle='--')

# Проекция Y-Z
axes[1].scatter(y[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[1].scatter(y[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[1].set_xlabel('Y (Npol)')
axes[1].set_ylabel('Spectrum (Px)')
axes[1].set_title('Проекция Y-Z')

# Проекция X-Y
sc1 = axes[2].scatter(x[~mask_cut], y[~mask_cut], c=z[~mask_cut], 
                     cmap='Blues', alpha=0.5, s=10)
sc2 = axes[2].scatter(x[mask_cut], y[mask_cut], c=z[mask_cut], 
                     cmap='Reds', alpha=0.8, s=20)
axes[2].set_xlabel('X (Ntor)')
axes[2].set_ylabel('Y (Npol)')
axes[2].set_title('Проекция X-Y')
axes[2].axvline(x=x_min, color='green', linestyle='--')
axes[2].axvline(x=x_max, color='green', linestyle='--')



plt.tight_layout()
plt.show()

# %%
# 2 peak right

if data.ndim == 2 and data.shape[1] >= 3:
    x = data[:, 0]  # первая координата
    y = data[:, 1]  # вторая координата  
    z = data[:, 2]  # значение спектра

    # Вырезаем область по X 
    x_min, x_max = 6.0, 11.0
    mask_cut = (x >= x_min) & (x <= x_max)
    
    # Применяем маску
    data_cut = data[mask_cut]
    x_cut = data_cut[:, 0]
    y_cut = data_cut[:, 1]
    z_cut = data_cut[:, 2]

np.savetxt('spec_right_2.dat', data_cut, delimiter=' ')

# Визуализация
fig = plt.figure(figsize=(12, 5))

# Полные данные
ax1 = fig.add_subplot(131, projection='3d')
sc1 = ax1.scatter(x, y, z, c=z, cmap='viridis')
ax1.set_title('Все данные')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Spectrum')

# Вырезанная область
ax2 = fig.add_subplot(132, projection='3d')
sc2 = ax2.scatter(x_cut, y_cut, z_cut, c=z_cut, cmap='viridis')
ax2.set_title(f'Вырезанная область: X ∈ [{x_min}, {x_max}]')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Spectrum')

# 2D карта
ax3 = fig.add_subplot(133)
sc3 = ax3.scatter(x, y, c=z, cmap='viridis', s=20)
ax3.set_title('2D Map - проекция X-Y')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
plt.colorbar(sc3, ax=ax3, label='Spectrum')


import matplotlib.patches as patches
rect = patches.Rectangle((x_min, y.min()), x_max - x_min, y.max() - y.min(),
                        linewidth=2, edgecolor='red', facecolor='none', linestyle='--')
ax3.add_patch(rect)
ax3.text(x_min, y.min(), 'Вырезанная\nобласть', color='red', va='top')

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Проекция X-Z
axes[0].scatter(x[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[0].scatter(x[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[0].set_xlabel('X (Ntor)')
axes[0].set_ylabel('Spectrum (Px)')
axes[0].set_title('Проекция X-Z')
axes[0].axvline(x=x_min, color='green', linestyle='--')
axes[0].axvline(x=x_max, color='green', linestyle='--')

# Проекция Y-Z
axes[1].scatter(y[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[1].scatter(y[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[1].set_xlabel('Y (Npol)')
axes[1].set_ylabel('Spectrum (Px)')
axes[1].set_title('Проекция Y-Z')

# Проекция X-Y
sc1 = axes[2].scatter(x[~mask_cut], y[~mask_cut], c=z[~mask_cut], 
                     cmap='Blues', alpha=0.5, s=10)
sc2 = axes[2].scatter(x[mask_cut], y[mask_cut], c=z[mask_cut], 
                     cmap='Reds', alpha=0.8, s=20)
axes[2].set_xlabel('X (Ntor)')
axes[2].set_ylabel('Y (Npol)')
axes[2].set_title('Проекция X-Y')
axes[2].axvline(x=x_min, color='green', linestyle='--')
axes[2].axvline(x=x_max, color='green', linestyle='--')



plt.tight_layout()
plt.show()

# %% [markdown]
# # Третьи пики

# %%
# 3 peak LEFT

if data.ndim == 2 and data.shape[1] >= 3:
    x = data[:, 0]  # первая координата
    y = data[:, 1]  # вторая координата  
    z = data[:, 2]  # значение спектра

    # Вырезаем область по X 
    x_min, x_max = -11.0, -7.5
    mask_cut = (x >= x_min) & (x <= x_max)
    
    # Применяем маску
    data_cut = data[mask_cut]
    x_cut = data_cut[:, 0]
    y_cut = data_cut[:, 1]
    z_cut = data_cut[:, 2]

np.savetxt('spec_left_3.dat', data_cut, delimiter=' ')

# Визуализация
fig = plt.figure(figsize=(12, 5))

# Полные данные
ax1 = fig.add_subplot(131, projection='3d')
sc1 = ax1.scatter(x, y, z, c=z, cmap='viridis')
ax1.set_title('Все данные')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Spectrum')

# Вырезанная область
ax2 = fig.add_subplot(132, projection='3d')
sc2 = ax2.scatter(x_cut, y_cut, z_cut, c=z_cut, cmap='viridis')
ax2.set_title(f'Вырезанная область: X ∈ [{x_min}, {x_max}]')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Spectrum')

# 2D карта
ax3 = fig.add_subplot(133)
sc3 = ax3.scatter(x, y, c=z, cmap='viridis', s=20)
ax3.set_title('2D Map - проекция X-Y')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
plt.colorbar(sc3, ax=ax3, label='Spectrum')


import matplotlib.patches as patches
rect = patches.Rectangle((x_min, y.min()), x_max - x_min, y.max() - y.min(),
                        linewidth=2, edgecolor='red', facecolor='none', linestyle='--')
ax3.add_patch(rect)
ax3.text(x_min, y.min(), 'Вырезанная\nобласть', color='red', va='top')

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Проекция X-Z
axes[0].scatter(x[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[0].scatter(x[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[0].set_xlabel('X (Ntor)')
axes[0].set_ylabel('Spectrum (Px)')
axes[0].set_title('Проекция X-Z')
axes[0].axvline(x=x_min, color='green', linestyle='--')
axes[0].axvline(x=x_max, color='green', linestyle='--')

# Проекция Y-Z
axes[1].scatter(y[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[1].scatter(y[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[1].set_xlabel('Y (Npol)')
axes[1].set_ylabel('Spectrum (Px)')
axes[1].set_title('Проекция Y-Z')

# Проекция X-Y
sc1 = axes[2].scatter(x[~mask_cut], y[~mask_cut], c=z[~mask_cut], 
                     cmap='Blues', alpha=0.5, s=10)
sc2 = axes[2].scatter(x[mask_cut], y[mask_cut], c=z[mask_cut], 
                     cmap='Reds', alpha=0.8, s=20)
axes[2].set_xlabel('X (Ntor)')
axes[2].set_ylabel('Y (Npol)')
axes[2].set_title('Проекция X-Y')
axes[2].axvline(x=x_min, color='green', linestyle='--')
axes[2].axvline(x=x_max, color='green', linestyle='--')



plt.tight_layout()
plt.show()

# %%
# 3 peak right

if data.ndim == 2 and data.shape[1] >= 3:
    x = data[:, 0]  # первая координата
    y = data[:, 1]  # вторая координата  
    z = data[:, 2]  # значение спектра

    # Вырезаем область по X 
    x_min, x_max = 11.0, 15.65
    mask_cut = (x >= x_min) & (x <= x_max)
    
    # Применяем маску
    data_cut = data[mask_cut]
    x_cut = data_cut[:, 0]
    y_cut = data_cut[:, 1]
    z_cut = data_cut[:, 2]

np.savetxt('spec_right_3.dat', data_cut, delimiter=' ')

# Визуализация
fig = plt.figure(figsize=(12, 5))

# Полные данные
ax1 = fig.add_subplot(131, projection='3d')
sc1 = ax1.scatter(x, y, z, c=z, cmap='viridis')
ax1.set_title('Все данные')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Spectrum')

# Вырезанная область
ax2 = fig.add_subplot(132, projection='3d')
sc2 = ax2.scatter(x_cut, y_cut, z_cut, c=z_cut, cmap='viridis')
ax2.set_title(f'Вырезанная область: X ∈ [{x_min}, {x_max}]')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Spectrum')

# 2D карта
ax3 = fig.add_subplot(133)
sc3 = ax3.scatter(x, y, c=z, cmap='viridis', s=20)
ax3.set_title('2D Map - проекция X-Y')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
plt.colorbar(sc3, ax=ax3, label='Spectrum')


import matplotlib.patches as patches
rect = patches.Rectangle((x_min, y.min()), x_max - x_min, y.max() - y.min(),
                        linewidth=2, edgecolor='red', facecolor='none', linestyle='--')
ax3.add_patch(rect)
ax3.text(x_min, y.min(), 'Вырезанная\nобласть', color='red', va='top')

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Проекция X-Z
axes[0].scatter(x[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[0].scatter(x[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[0].set_xlabel('X (Ntor)')
axes[0].set_ylabel('Spectrum (Px)')
axes[0].set_title('Проекция X-Z')
axes[0].axvline(x=x_min, color='green', linestyle='--')
axes[0].axvline(x=x_max, color='green', linestyle='--')

# Проекция Y-Z
axes[1].scatter(y[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[1].scatter(y[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[1].set_xlabel('Y (Npol)')
axes[1].set_ylabel('Spectrum (Px)')
axes[1].set_title('Проекция Y-Z')

# Проекция X-Y
sc1 = axes[2].scatter(x[~mask_cut], y[~mask_cut], c=z[~mask_cut], 
                     cmap='Blues', alpha=0.5, s=10)
sc2 = axes[2].scatter(x[mask_cut], y[mask_cut], c=z[mask_cut], 
                     cmap='Reds', alpha=0.8, s=20)
axes[2].set_xlabel('X (Ntor)')
axes[2].set_ylabel('Y (Npol)')
axes[2].set_title('Проекция X-Y')
axes[2].axvline(x=x_min, color='green', linestyle='--')
axes[2].axvline(x=x_max, color='green', linestyle='--')



plt.tight_layout()
plt.show()

# %% [markdown]
# # 4-ый пик

# %%
# 4 peak LEFT

if data.ndim == 2 and data.shape[1] >= 3:
    x = data[:, 0]  # первая координата
    y = data[:, 1]  # вторая координата  
    z = data[:, 2]  # значение спектра

    # Вырезаем область по X 
    x_min, x_max = -15.65, -11.0
    mask_cut = (x >= x_min) & (x <= x_max)
    
    # Применяем маску
    data_cut = data[mask_cut]
    x_cut = data_cut[:, 0]
    y_cut = data_cut[:, 1]
    z_cut = data_cut[:, 2]

np.savetxt('spec_left_4.dat', data_cut, delimiter=' ')

# Визуализация
fig = plt.figure(figsize=(12, 5))

# Полные данные
ax1 = fig.add_subplot(131, projection='3d')
sc1 = ax1.scatter(x, y, z, c=z, cmap='viridis')
ax1.set_title('Все данные')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Spectrum')

# Вырезанная область
ax2 = fig.add_subplot(132, projection='3d')
sc2 = ax2.scatter(x_cut, y_cut, z_cut, c=z_cut, cmap='viridis')
ax2.set_title(f'Вырезанная область: X ∈ [{x_min}, {x_max}]')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Spectrum')

# 2D карта
ax3 = fig.add_subplot(133)
sc3 = ax3.scatter(x, y, c=z, cmap='viridis', s=20)
ax3.set_title('2D Map - проекция X-Y')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
plt.colorbar(sc3, ax=ax3, label='Spectrum')


import matplotlib.patches as patches
rect = patches.Rectangle((x_min, y.min()), x_max - x_min, y.max() - y.min(),
                        linewidth=2, edgecolor='red', facecolor='none', linestyle='--')
ax3.add_patch(rect)
ax3.text(x_min, y.min(), 'Вырезанная\nобласть', color='red', va='top')

plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Проекция X-Z
axes[0].scatter(x[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[0].scatter(x[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[0].set_xlabel('X (Ntor)')
axes[0].set_ylabel('Spectrum (Px)')
axes[0].set_title('Проекция X-Z')
axes[0].axvline(x=x_min, color='green', linestyle='--')
axes[0].axvline(x=x_max, color='green', linestyle='--')

# Проекция Y-Z
axes[1].scatter(y[~mask_cut], z[~mask_cut], c='blue', alpha=0.3, s=10)
axes[1].scatter(y[mask_cut], z[mask_cut], c='red', alpha=0.8, s=20)
axes[1].set_xlabel('Y (Npol)')
axes[1].set_ylabel('Spectrum (Px)')
axes[1].set_title('Проекция Y-Z')

# Проекция X-Y
sc1 = axes[2].scatter(x[~mask_cut], y[~mask_cut], c=z[~mask_cut], 
                     cmap='Blues', alpha=0.5, s=10)
sc2 = axes[2].scatter(x[mask_cut], y[mask_cut], c=z[mask_cut], 
                     cmap='Reds', alpha=0.8, s=20)
axes[2].set_xlabel('X (Ntor)')
axes[2].set_ylabel('Y (Npol)')
axes[2].set_title('Проекция X-Y')
axes[2].axvline(x=x_min, color='green', linestyle='--')
axes[2].axvline(x=x_max, color='green', linestyle='--')



plt.tight_layout()
plt.show()
